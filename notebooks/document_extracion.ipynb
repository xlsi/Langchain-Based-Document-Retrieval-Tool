# %%
import pandas as pd
import re


# doc load
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import TokenTextSplitter


# schema
from typing import List
from langchain_core.pydantic_v1 import BaseModel, Field


# extractor
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_core.messages import SystemMessage

FILE = "../data/input/1. SGX Group reports 1H FY2024 net profit of S$251 million.pdf"

# %% [markdown]
# ## Read Files

# %%
# Load PDF file and split into pages
pages = PyPDFLoader(FILE).load_and_split()

# Clean up page content by replacing multiple newlines with a single one
text = " ".join(re.sub("\n \n+", "\n", page.page_content) for page in pages)

text
# Out:
# 'Singapore Exchange Limited  \nCompany Reg No. 199904940D  \n2 Shenton Way, #02 -02 SGX Centre 1, Singapore 068804  \nmain: +65 6236 8888   fax: +65 6535 6994  \nsgx.com  \n  \n   \n \n \nNews Release  \n1 February 202 4 \nSGX Group reports 1H FY2024 net profit of S$251 million  \n1H FY202 4 Financial Summary  \n 1H FY2024  1H FY2024  Adjusted * \nRevenue  S$592.2 million, up 3.6%  \nEBITDA  S$344.6 million, up 3.2%  S$344.6 million, up 3.2%  \nNet profit attributable to equity holders \nof the company (NPAT)  S$281.6 million, down 1.0%  S$251.4 million, up 6.2%  \nEarnings per share (EPS)  26.3 cents  23.5 cents  \nInterim quarterly dividend per share  8.5 cents, up 0.5 cents  \n* Adjusted EBITDA, NPAT and EPS exclude certain non -cash and non -recurring items that have less bearing on SGX’s \noperating performance. Hence, they better reflect the group’s underlying performance. Adjusted figures are non -SFRS(I) \nmeasures. Please refer to Section 7 of our financial results for reconciliations between the adjusted and their equivalent \nmeasures.  \nAll figures are for the year except for figures in brackets, which are for the year earlier unless otherwise stated. Figures may \nbe subject to rounding.  \nThe presentation of revenue in our 1H FY2024 income statement has been revised to the following four operating segments \n– Fixed Income, Currencies and Commodities; Equities – Cash; Equities – Derivatives; and Platform and Others1. 1H FY2023 \nrevenue h as been reclassified to the four operating segments for a like -for-like comparison against 1H FY2024.  \nSingapore Exchange (SGX  Group ) today reported 1H FY202 4 adjusted net profit of S$ 251.4  million \n(S$2 36.8 million).  Adjusted EBITDA rose to  S$344.6 million ( S$334.1 million) , while  adjusted earnings \nper share increased to  23.5 cents (22.2 cents).  \nRevenue  increased 3.6% to S$592.2 million ( S$571.4 million), mainly driven by higher revenues from \nCurrencies and Commodities2 and Platform and Others, partially offset by lower Equities – Cash2 and \nEquities – Derivatives2 revenue.  \nThe Board of Directors has declared an interim quarterly dividend of 8.5 cents (8.0 cents) per share, \npayable on 20 February 2024. This brings total dividends in 1H FY2024 to 17.0 cents (16.0 cents) per \nshare.  \nLoh Boon Chye, Chief Executive Officer of SGX Group, said, “Our multi -asset offering continued to \nserve our customers well in a persistently challenging macro environment . Our currenc y and \ncommodit y derivatives  business has been a growing contributor to revenue , and our OTC FX \n1 Please refer to Section 20 (b) of our financial results for full disclosure on the restatement to presentation of income \nstatement and segment information.  \n2 Includes associated treasury income. Total treasury income grew by S$20.2 million. Singapore Exchange Limited  \nCompany Reg No. 199904940D  \n2 Shenton Way, #02 -02 SGX Centre 1, Singapore 068804  \nmain: +65 6236 8888   fax: +65 6535 6994  \nsgx.com  \n franchise is making good progress with  average daily volume consistently reach ing US$100 billion in \nrecent  months .” \n“The year ahead could see muted  global economic growth and geo political concerns  that may affect \nmarket sentiment  and risk appetite. Nonetheless, the resi lience of o ur multi -asset strategy  as well as  \nhealthy financial position and discipline will enable us to capitalise on  conditions across cycles.  To \ndrive growth, we will focus on expanding our solutions  to capture opportunities in Asia , grow  our \nemerging products and further strengthen our global distribution and network ,” added Mr. Loh.  \nResults Summary  \nFixed Income, Currencies and Commodities (FICC)   \nFICC revenue increased 28.1% to S$151.9 million ( S$118.5 million) and accounted for 25.6% (20.7%) \nof total revenue3. \nFICC – Fixed  Income  \nFixed Income revenue decreased 8.4% to S$3.9 million ( S$4.3 million).  \n▪ Listing revenue: S$2.5 million, down 1.4%  f ...

# %%
text_splitter = TokenTextSplitter(
    # you may try different chunk_size and chunk_overlap for a better extraction
    chunk_size=1000,
    chunk_overlap=20,
)

texts = text_splitter.split_text(text)
len(texts)
# Out:
# 4

# %% [markdown]
# ## The Schema

# %%
# Reference
# * https://python.langchain.com/v0.2/docs/tutorials/extraction/
# * https://blog.langchain.dev/open-source-extraction-service/

class FinancialCategory(BaseModel):
    """Information about a financial category"""

    # ^ Doc-string for the entity FinancialCategory.
    # This doc-string is sent to the LLM as the description of the schema FinancialCategory,
    # and it can help to improve extraction results.

    # Note that:
    # 1. In the original article, each field is an `optional` -- this allows the model to decline to extract it! You could have a try.
    # 2. Each field has a `description` -- this description is used by the LLM.
    # Having a good description can help improve extraction results.
    name: str = Field(description="Name of the financial figure, such as total revenue.")
    value: str = Field(description="Complete value of the financial figure, including numbers, currency symbols, and scale (e.g., $123 million).")
    period: str = Field(description="Reported period of the financial figure.")
    source_sentence: str = Field(description="Source sentence of text where financial figure was found.")


class Data(BaseModel):
    """Extracted data about financial category."""

    # Creates a model so that we can extract multiple entities.
    finfigure: List[FinancialCategory]

# %% [markdown]
# ## The Extractor

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        SystemMessage(
            content=
            (
                "Your goal is to extract structured information from the user's input that matches the form described below. "
                "When extracting information, please make sure it matches the type information exactly. "
                "Do not add any attributes that do not appear in the schema shown below. "
                """
                TypeScript
                financial_figure: { // Extract financial figures from the text, including their names, values, reported periods, and source sentences.
                    name: string // Name of the financial figure, such as revenue, expense, NPAT, EBITDA
                    value: string // Complete value of the financial figure, including numbers, currency symbols, and scale (e.g., $123 million)
                    period: string // Reported period for the financial figure.
                    source_sentence: string // The sentence from the text where this financial figure is mentioned.
                }                
                """
                "Please output the extracted information in JSON format. Do not output anything except for the extracted information. "
                "Do not add any clarifying information. Do not add any fields that are not in the schema. If the text contains attributes that do not appear in the schema, please return null. "
                "All output must be in JSON format and follow the schema specified above. Wrap the JSON in <json> tags."
                "Below are some examples"
                """
                Input: In the first quarter of 2021, Company A reported a revenue of $500 million
                Output: <json>{"financial_figure": {"name": "revenue", "value": "$500 million", "period": "first quarter of 2021", "source_sentence": "In the first quarter of 2021, Company A reported a revenue of $500 million."}}</json>
                Input: The total expenses for fiscal year 2020 were approximately $200 million
                Output: <json>{"financial_figure": {"name": "expenses", "value": "$200 million", "period": "fiscal year 2020", "source_sentence": "The total expenses for fiscal year 2020 were approximately $200 million."}}</json>                
                """
            )
        ),
        # Placeholder for user input.
        HumanMessagePromptTemplate.from_template("{text}"),
    ]
)

# %%
prompt.messages
# Out:
# [SystemMessage(content='Your goal is to extract structured information from the user\'s input that matches the form described below. When extracting information, please make sure it matches the type information exactly. Do not add any attributes that do not appear in the schema shown below. \n                TypeScript\n                financial_figure: { // Extract financial figures from the text, including their names, values, reported periods, and source sentences.\n                    name: string // Name of the financial figure, such as revenue, expense, NPAT, EBITDA\n                    value: string // Complete value of the financial figure, including numbers, currency symbols, and scale (e.g., $123 million)\n                    period: string // Reported period for the financial figure.\n                    source_sentence: string // The sentence from the text where this financial figure is mentioned.\n                }                \n                Please output the extracted information in JSON format. Do not output anything except for the extracted information. Do not add any clarifying information. Do not add any fields that are not in the schema. If the text contains attributes that do not appear in the schema, please return null. All output must be in JSON format and follow the schema specified above. Wrap the JSON in <json> tags.Below are some examples\n                Input: In the first quarter of 2021, Company A reported a revenue of $500 million\n                Output: <json>{"financial_figure": {"name": "revenue", "value": "$500 million", "period": "first quarter of 2021", "source_sentence": "In the first quarter of 2021, Company A reported a revenue of $500 million."}}</json>\n                Input: The total expenses for fiscal year 2020 were approximately $200 million\n                Output: <json>{"financial_figure": {"name": "expenses", "value": "$200 million", "period": "fiscal year 2020", "source_sentence": "The total expenses for fiscal year 2020 were approximately $200 million."}}</json>                \n                '),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['text'], template='{text}'))]

# %%
from langchain_mistralai import ChatMistralAI
from langchain_openai import ChatOpenAI

llm = ChatMistralAI(
    api_key="",
    model_name="mistral-large-latest",
    temperature=0,
    max_tokens=32000
)

# llm = ChatOpenAI(
#     api_key="",
#     model="gpt-4-1106-preview",
#     temperature=0)

runnable = prompt | llm.with_structured_output(
    schema=Data,
    include_raw=True,
    )

# %% [markdown]
# ## Extract

# %%
extractions = [runnable.invoke({"text": text}) for text in texts]
extractions
# Out:
# [{'raw': AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'BwHmaFogK', 'function': {'name': 'Data', 'arguments': '{"finfigure": [{"name": "revenue", "value": "S$592.2 million", "period": "1H FY2024", "source_sentence": "Revenue increased 3.6% to S$592.2 million ( S$571.4 million), mainly driven by higher revenues from Currencies and Commodities2 and Platform and Others, partially offset by lower Equities \\u2013 Cash2 and Equities \\u2013 Derivatives2 revenue."}, {"name": "adjusted EBITDA", "value": "S$344.6 million", "period": "1H FY2024", "source_sentence": "Adjusted EBITDA rose to S$344.6 million ( S$334.1 million) , while adjusted earnings per share increased to 23.5 cents (22.2 cents)."}, {"name": "adjusted net profit", "value": "S$251.4 million", "period": "1H FY2024", "source_sentence": "Singapore Exchange (SGX Group ) today reported 1H FY202 4 adjusted net profit of S$ 251.4 million (S$2 36.8 million)."}]}'}}]}, response_metadata={'token_usage': {'prompt_tokens': 1863, 'total_tokens': 2167, 'completion_tokens': 304}, 'model': 'mistral-large-latest', 'finish_reason': 'tool_calls'}, id='run-8f01e37a-9edd-446b-94d3-eed739460995-0', tool_calls=[{'name': 'Data', 'args': {'finfigure': [{'name': 'revenue', 'value': 'S$592.2 million', 'period': '1H FY2024', 'source_sentence': 'Revenue increased 3.6% to S$592.2 million ( S$571.4 million), mainly driven by higher revenues from Currencies and Commodities2 and Platform and Others, partially offset by lower Equities – Cash2 and Equities – Derivatives2 revenue.'}, {'name': 'adjusted EBITDA', 'value': 'S$344.6 million', 'period': '1H FY2024', 'source_sentence': 'Adjusted EBITDA rose to S$344.6 million ( S$334.1 million) , while adjusted earnings per share increased to 23.5 cents (22.2 cents).'}, {'name': 'adjusted net profit', 'value': 'S$251.4 million', 'period': '1H FY2024', 'source_sentence': 'Singapore Exchange (SGX Group ) today reported 1H FY202 4 adjusted net profit of S$ 251.4 million (S$2 36.8 million).'}]}, 'id': 'BwHmaFogK'}], usage_metadata={'input_tokens': 1863, 'output_tokens': 304, 'total_tokens': 2167}),
#   'parsed': Data(finfigure=[FinancialCategory(name='revenue', value='S$592.2 million', period='1H FY2024', source_sentence='Revenue increased 3.6% to S$592.2 million ( S$571.4 million), mainly driven by higher revenues from Currencies and Commodities2 and Platform and Others, partially offset by lower Equities – Cash2 and Equities – Derivatives2 revenue.'), FinancialCategory(name='adjusted EBITDA', value='S$344.6 million', period='1H FY2024', source_sentence='Adjusted EBITDA rose to S$344.6 million ( S$334.1 million) , while adjusted earnings per share increased to 23.5 cents (22.2 cents).'), FinancialCategory(name='adjusted net profit', value='S$251.4 million', period='1H FY2024', source_sentence='Singapore Exchange (SGX Group ) today reported 1H FY202 4 adjusted net profit of S$ 251.4 million (S$2 36.8 million).')]),
#   'parsing_error': None},
#  {'raw': AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'zCC8GJMnj', 'function': {'name': 'Data', 'arguments': '{"finfigure": [{"name": "FICC revenue", "value": "$151.9 million", "period": "not specified", "source_sentence": "FICC revenue increased 28.1% to S$151.9 million ( S$118.5 million) and accounted for 25.6% (20.7%) of total revenue3."}, {"name": "Fixed Income revenue", "value": "$3.9 million", "period": "not specified", "source_sentence": "Fixed Income revenue decreased 8.4% to S$3.9 million ( S$4.3 million)."}, {"name": "Listing revenue", "value": "$2.5 million", "period": "not specified", "source_sentence": "Listing revenue: S$2.5 million, down 1.4% from S$2.6 million."}, {"name": "Corporate actions and other revenue", "value": "$1.4 million", "period": "not specified", "source_sentence": "Corporate actions and other revenue: S$1.4 million, down 19.1% from S$1.7 million."}, {"name": "Currencies and Commodities revenue", "value": "$148.0 million", "period": "not specified", "source_sentence": "Currencies and Commodities revenue increased 29.5% to S$148.0 million ( S$114.3 million)."}, {"name": "OTC FX revenue", "value": "$40.9 million", "period": "not specified", "source_sentence": "OTC FX revenue was S$40.9 million ( S$36.2 million) and accounted for 27.7% (31.7%) of Currencies and Commodities revenue."}, {"name": "Trading and clearing revenue", "value": "$111.3 million", "period": "not specified", "source_sentence": "Trading and clearing revenue: S$111.3 million, up 25.3% from S$88.8 million."}, {"name": "Treasury and other revenue", "value": "$36.7 million", "period": "not specified", "source_sentence": "Treasury and other revenue: S$36.7 million, up 44.3% from S$25.4 million."}, {"name": "Equities \\u2013 Cash revenue", "value": "$159.6 million", "period": "not specified", "source_sentence": "Equities \\u2013 Cash revenue declined by 5.6% to S$159.6 million ( S$169.1 million ) and accounted for 26.9 % (29.6 %) of total revenue."}, {"name": "Listing revenue", "value": "$14.6 million", "period": "not specified", "source_sentence": "Listing revenue: S$14.6 million, down 3.3% from S$15.1 million."}, {"name": "Trading and clearing revenue", "value": "$77.2 million", "period": "not specified", "source_sentence": "Trading and clearing revenue: S$77.2 million, down 13.9 % from S$89.6 million."}, {"name": "Securities settlement, depository management, corporate actions and other revenue", "value": "$67.9 million", "period": "not specified", "source_sentence": "Securities settlement, depository management, corporate actions and other revenue: S$67.9 million, up 5.3% from S$64.5 million."}]}'}}]}, response_metadata={'token_usage': {'prompt_tokens': 1810, 'total_tokens': 2681, 'completion_tokens': 871}, 'model': 'mistral-large-latest', 'finish_reason': 'tool_calls'}, id='run-5de5a65c-d1f6-47c3-bce0-7517a0cc4efc-0', tool_calls=[{'name': 'Data', 'args': {'finfigure': [{'name': 'FICC revenue', 'value': '$151.9 million', 'period': 'not specified', 'source_sentence': 'FICC revenue increased 28.1% to S$151.9 million ( S$118.5 million) and accounted for 25.6% (20.7%) of total revenue3.'}, {'name': 'Fixed Income revenue', 'value': '$3.9 million', 'period': 'not specified', 'source_sentence': 'Fixed Income revenue decreased 8.4% to S$3.9 million ( S$4.3 million).'}, {'name': 'Listing revenue', 'value': '$2.5 million', 'period': 'not specified', 'source_sentence': 'Listing revenue: S$2.5 million, down 1.4% from S$2.6 million.'}, {'name': 'Corporate actions and other revenue', 'value': '$1.4 million', 'period': 'not specified', 'source_sentence': 'Corporate actions and other revenue: S$1.4 million, down 19.1% from S$1.7 million.'}, {'name': 'Currencies and Commodities revenue', 'value': '$148.0 million', 'period': 'not specified', 'source_sentence': 'Currencies and Commodities revenue increased 29.5% to S$148.0 million ( S$114.3 million).'}, {'name': 'OTC FX revenue', 'value': '$40.9 million', 'period': 'not specified',  ...
#   'parsed': Data(finfigure=[FinancialCategory(name='FICC revenue', value='$151.9 million', period='not specified', source_sentence='FICC revenue increased 28.1% to S$151.9 million ( S$118.5 million) and accounted for 25.6% (20.7%) of total revenue3.'), FinancialCategory(name='Fixed Income revenue', value='$3.9 million', period='not specified', source_sentence='Fixed Income revenue decreased 8.4% to S$3.9 million ( S$4.3 million).'), FinancialCategory(name='Listing revenue', value='$2.5 million', period='not specified', source_sentence='Listing revenue: S$2.5 million, down 1.4% from S$2.6 million.'), FinancialCategory(name='Corporate actions and other revenue', value='$1.4 million', period='not specified', source_sentence='Corporate actions and other revenue: S$1.4 million, down 19.1% from S$1.7 million.'), FinancialCategory(name='Currencies and Commodities revenue', value='$148.0 million', period='not specified', source_sentence='Currencies and Commodities revenue increased 29.5% to S$148.0 million ( S$114.3 million).'), FinancialCategory(name='OTC FX revenue', value='$40.9 million', period='not specified', source_sentence='OTC FX revenue was S$40.9 million ( S$36.2 million) and accounted for 27.7% (31.7%) of Currencies and Commodities revenue.'), FinancialCategory(name='Trading and clearing revenue', value='$111.3 million', period='not specified', source_sentence='Trading and clearing revenue: S$111.3 million, up 25.3% from S$88.8 million.'), FinancialCategory(name='Treasury and other revenue', value='$36.7 million', period='not specified', source_sentence='Treasury and other revenue: S$36.7 million, up 44.3% from S$25.4 million.'), FinancialCategory(name='Equities – Cash revenue', value='$159.6 million', period='not specified', source_sentence='Equities – Cash revenue declined by 5.6% to S$159.6 million ( S$169.1 million ) and accounted for 26.9 % (29.6 %) of total revenue.'), FinancialCategory(name='Listing revenue', value='$14.6 million', period='not specified', source_sentence='Listing revenue: S$14.6 million, down 3.3% from S$15.1 million.'), FinancialCategory(name='Trading and clearing revenue', value='$77.2 million', period='not specified', source_sentence='Trading and clearing revenue: S$77.2 million, down 13.9 % from S$89.6 million.'), FinancialCategory(name='Securities settlement, depository management, corporate actions and other revenue', value='$67.9 million', period='not specified', source_sentence='Securities settlement, depository management, corporate actions and other revenue: S$67.9 million, up 5.3% from S$64.5 million.')]),
#   'parsing_error': None},
#  {'raw': AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'P48xha6Jf', 'function': {'name': 'Data', 'arguments': '{"finfigure": [{"name": "trading and clearing revenue", "value": "$123.2 million", "period": "1H FY2024", "source_sentence": "Trading and clearing revenue: S$123.2 million, down 15.3 % from S$145.4 million"}, {"name": "treasury and other revenue", "value": "$37.5 million", "period": "1H FY2024", "source_sentence": "Treasury and other revenue: S$37.5 million, up 37.7% from S$27.2 million"}, {"name": "market data revenue", "value": "$24.2 million", "period": "1H FY2024", "source_sentence": "Market data revenue: S$24.2 million, up 9.9% from S$22.0 million"}, {"name": "connectivity revenue", "value": "$38.5 million", "period": "1H FY2024", "source_sentence": "Connectivity revenue: S$38.5 million, up 8.7% from S$35.4 million"}, {"name": "indices and other revenue", "value": "$57.4 million", "period": "1H FY2024", "source_sentence": "Indices and other revenue: S$57.4 million, up 6.8% from S$53.8 million"}]}'}}]}, response_metadata={'token_usage': {'prompt_tokens': 1838, 'total_tokens': 2199, 'completion_tokens': 361}, 'model': 'mistral-large-latest', 'finish_reason': 'tool_calls'}, id='run-5ebd4deb-fd7e-4030-857e-95ace411b26f-0', tool_calls=[{'name': 'Data', 'args': {'finfigure': [{'name': 'trading and clearing revenue', 'value': '$123.2 million', 'period': '1H FY2024', 'source_sentence': 'Trading and clearing revenue: S$123.2 million, down 15.3 % from S$145.4 million'}, {'name': 'treasury and other revenue', 'value': '$37.5 million', 'period': '1H FY2024', 'source_sentence': 'Treasury and other revenue: S$37.5 million, up 37.7% from S$27.2 million'}, {'name': 'market data revenue', 'value': '$24.2 million', 'period': '1H FY2024', 'source_sentence': 'Market data revenue: S$24.2 million, up 9.9% from S$22.0 million'}, {'name': 'connectivity revenue', 'value': '$38.5 million', 'period': '1H FY2024', 'source_sentence': 'Connectivity revenue: S$38.5 million, up 8.7% from S$35.4 million'}, {'name': 'indices and other revenue', 'value': '$57.4 million', 'period': '1H FY2024', 'source_sentence': 'Indices and other revenue: S$57.4 million, up 6.8% from S$53.8 million'}]}, 'id': 'P48xha6Jf'}], usage_metadata={'input_tokens': 1838, 'output_tokens': 361, 'total_tokens': 2199}),
#   'parsed': Data(finfigure=[FinancialCategory(name='trading and clearing revenue', value='$123.2 million', period='1H FY2024', source_sentence='Trading and clearing revenue: S$123.2 million, down 15.3 % from S$145.4 million'), FinancialCategory(name='treasury and other revenue', value='$37.5 million', period='1H FY2024', source_sentence='Treasury and other revenue: S$37.5 million, up 37.7% from S$27.2 million'), FinancialCategory(name='market data revenue', value='$24.2 million', period='1H FY2024', source_sentence='Market data revenue: S$24.2 million, up 9.9% from S$22.0 million'), FinancialCategory(name='connectivity revenue', value='$38.5 million', period='1H FY2024', source_sentence='Connectivity revenue: S$38.5 million, up 8.7% from S$35.4 million'), FinancialCategory(name='indices and other revenue', value='$57.4 million', period='1H FY2024', source_sentence='Indices and other revenue: S$57.4 million, up 6.8% from S$53.8 million')]),
#   'parsing_error': None},
#  {'raw': AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'LkulKym62', 'function': {'name': 'Data', 'arguments': '{"finfigure": [{"name": "net profit", "value": "S$289.7 million", "period": "first half of FY2024", "source_sentence": "5% to S$289.7 million (S$279.9 million), which excludes amortisation of purchased intangible assets."}, {"name": "total capital expenditure", "value": "S$18.5 million", "period": "not specified", "source_sentence": "Total capital expenditure was S$18.5 million ( S$17.8 million). These investments include upgrades to our Titan OTC trade reporting system, modernisation of our technology infrastructure and consolidation of our office spaces."}, {"name": "expenses", "value": "not specified", "period": "FY2024", "source_sentence": "Expense growth in FY2024 is likely to be similar to the 3% year -on-year expense growth rate observed in the first half of FY2024, lower than the previously guided mid -single digit percentage range."}, {"name": "projected capital expenditure", "value": "S$70-75 million", "period": "FY2024", "source_sentence": "Our projected capital expenditure for FY2024 is anticipated to be within S$70-75 million, lower than our previously guided S$75-80 million range."}]}'}}]}, response_metadata={'token_usage': {'prompt_tokens': 1446, 'total_tokens': 1795, 'completion_tokens': 349}, 'model': 'mistral-large-latest', 'finish_reason': 'tool_calls'}, id='run-ba18387b-4db2-4d28-9fca-fbc273e57a5e-0', tool_calls=[{'name': 'Data', 'args': {'finfigure': [{'name': 'net profit', 'value': 'S$289.7 million', 'period': 'first half of FY2024', 'source_sentence': '5% to S$289.7 million (S$279.9 million), which excludes amortisation of purchased intangible assets.'}, {'name': 'total capital expenditure', 'value': 'S$18.5 million', 'period': 'not specified', 'source_sentence': 'Total capital expenditure was S$18.5 million ( S$17.8 million). These investments include upgrades to our Titan OTC trade reporting system, modernisation of our technology infrastructure and consolidation of our office spaces.'}, {'name': 'expenses', 'value': 'not specified', 'period': 'FY2024', 'source_sentence': 'Expense growth in FY2024 is likely to be similar to the 3% year -on-year expense growth rate observed in the first half of FY2024, lower than the previously guided mid -single digit percentage range.'}, {'name': 'projected capital expenditure', 'value': 'S$70-75 million', 'period': 'FY2024', 'source_sentence': 'Our projected capital expenditure for FY2024 is anticipated to be within S$70-75 million, lower than our previously guided S$75-80 million range.'}]}, 'id': 'LkulKym62'}], usage_metadata={'input_tokens': 1446, 'output_tokens': 349, 'total_tokens': 1795}),
#   'parsed': Data(finfigure=[FinancialCategory(name='net profit', value='S$289.7 million', period='first half of FY2024', source_sentence='5% to S$289.7 million (S$279.9 million), which excludes amortisation of purchased intangible assets.'), FinancialCategory(name='total capital expenditure', value='S$18.5 million', period='not specified', source_sentence='Total capital expenditure was S$18.5 million ( S$17.8 million). These investments include upgrades to our Titan OTC trade reporting system, modernisation of our technology infrastructure and consolidation of our office spaces.'), FinancialCategory(name='expenses', value='not specified', period='FY2024', source_sentence='Expense growth in FY2024 is likely to be similar to the 3% year -on-year expense growth rate observed in the first half of FY2024, lower than the previously guided mid -single digit percentage range.'), FinancialCategory(name='projected capital expenditure', value='S$70-75 million', period='FY2024', source_sentence='Our projected capital expenditure for FY2024 is anticipated to be within S$70-75 million, lower than our previously guided S$75-80 million range.')]),
#   'parsing_error': None}]

# %%
result_df = pd.DataFrame()

for extraction in extractions:
    result_df = pd.concat([
        result_df,
        pd.DataFrame(data.dict() for data in extraction['parsed'].finfigure)
        ])
result_df
# Out:
#                                                  name            value  \
# 0                                             revenue  S$592.2 million
# 1                                     adjusted EBITDA  S$344.6 million
# 2                                 adjusted net profit  S$251.4 million
# 0                                        FICC revenue   $151.9 million
# 1                                Fixed Income revenue     $3.9 million
# 2                                     Listing revenue     $2.5 million
# 3                 Corporate actions and other revenue     $1.4 million
# 4                  Currencies and Commodities revenue   $148.0 million
# 5                                      OTC FX revenue    $40.9 million
# 6                        Trading and clearing revenue   $111.3 million
# 7                          Treasury and other revenue    $36.7 million
# 8                             Equities – Cash revenue   $159.6 million
# 9                                     Listing revenue    $14.6 million
# 10                       Trading and clearing revenue    $77.2 million
# 11  Securities settlement, depository management, ...    $67.9 million
# 0                        trading and clearing revenue   $123.2 million
# 1                          treasury and other revenue    $37.5 million
# 2                                 market data revenue    $24.2 million
# 3                                connectivity revenue    $38.5 million
# 4                           indices and other revenue    $57.4 million
# 0                                          net profit  S$289.7 million
# 1                           total capital expenditure   S$18.5 million
# 2                                            expenses    not specified
# 3                       projected capital expenditure  S$70-75 million
#
#                   period                                    source_sentence
# 0              1H FY2024  Revenue increased 3.6% to S$592.2 million ( S$...
# 1              1H FY2024  Adjusted EBITDA rose to S$344.6 million ( S$33...
# 2              1H FY2024  Singapore Exchange (SGX Group ) today reported...
# 0          not specified  FICC revenue increased 28.1% to S$151.9 millio...
# 1          not specified  Fixed Income revenue decreased 8.4% to S$3.9 m...
# 2          not specified  Listing revenue: S$2.5 million, down 1.4% from...
# 3          not specified  Corporate actions and other revenue: S$1.4 mil...
# 4          not specified  Currencies and Commodities revenue increased 2...
# 5          not specified  OTC FX revenue was S$40.9 million ( S$36.2 mil...
# 6          not specified  Trading and clearing revenue: S$111.3 million,...
# 7          not specified  Treasury and other revenue: S$36.7 million, up...
# 8          not specified  Equities – Cash revenue declined by 5.6% to S$...
# 9          not specified  Listing revenue: S$14.6 million, down 3.3% fro...
# 10         not specified  Trading and clearing revenue: S$77.2 million, ...
# 11         not specified  Securities settlement, depository management, ...
# 0              1H FY2024  Trading and clearing revenue: S$123.2 million,...
# 1              1H FY2024  Treasury and other revenue: S$37.5 million, up...
# 2              1H FY2024  Market data revenue: S$24.2 million, up 9.9% f...
# 3              1H FY2024  Connectivity revenue: S$38.5 million, up 8.7% ...
# 4              1H FY2024  Indices and other revenue: S$57.4 million, up ...
# 0   first half of FY2024  5% to S$289.7 million (S$279.9 million), which...
# 1          not specified  Total capital expenditure was S$18.5 million (...
# 2                 FY2024  Expense growth in FY2024 is likely to be simil...
# 3                 FY2024  Our projected capital expenditure for FY2024 i...

# %%
result_df.to_csv('../data/output/extractions.csv', index=False)

# %%
result_df = pd.read_csv('../data/output/extractions.csv')
print(result_df.to_markdown())
# Out:
# |    | name                                                                              | value           | period               | source_sentence                                                                                                                                                                                                                          |
# |---:|:----------------------------------------------------------------------------------|:----------------|:---------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | revenue                                                                           | S$592.2 million | 1H FY2024            | Revenue increased 3.6% to S$592.2 million ( S$571.4 million), mainly driven by higher revenues from Currencies and Commodities2 and Platform and Others, partially offset by lower Equities – Cash2 and Equities – Derivatives2 revenue. |
# |  1 | adjusted EBITDA                                                                   | S$344.6 million | 1H FY2024            | Adjusted EBITDA rose to S$344.6 million ( S$334.1 million) , while adjusted earnings per share increased to 23.5 cents (22.2 cents).                                                                                                     |
# |  2 | adjusted net profit                                                               | S$251.4 million | 1H FY2024            | Singapore Exchange (SGX Group ) today reported 1H FY202 4 adjusted net profit of S$ 251.4 million (S$2 36.8 million).                                                                                                                    |
# |  3 | FICC revenue                                                                      | $151.9 million  | not specified        | FICC revenue increased 28.1% to S$151.9 million ( S$118.5 million) and accounted for 25.6% (20.7%) of total revenue3.                                                                                                                    |
# |  4 | Fixed Income revenue                                                              | $3.9 million    | not specified        | Fixed Income revenue decreased 8.4% to S$3.9 million ( S$4.3 million).                                                                                                                                                                   |
# |  5 | Listing revenue                                                                   | $2.5 million    | not specified        | Listing revenue: S$2.5 million, down 1.4% from S$2.6 million.                                                                                                                                                                            |
# |  6 | Corporate actions and other revenue                                               | $1.4 million    | not specified        | Corporate actions and other revenue: S$1.4 million, down 19.1% from S$1.7 million.                                                                                                                                                       |
# |  7 | Currencies and Commodities revenue                                                | $148.0 million  | not specified        | Currencies and Commodities revenue increased 29.5% to S$148.0 million ( S$114.3 million).                                                                                                                                                |
# |  8 | OTC FX revenue                                                                    | $40.9 million   | not specified        | OTC FX revenue was S$40.9 million ( S$36.2 million) and accounted for 27.7% (31.7%) of Currencies and Commodities revenue.                                                                                                               |
# |  9 | Trading and clearing revenue                                                      | $111.3 million  | not specified        | Trading and clearing revenue: S$111.3 million, up 25.3% from S$88.8 million.                                                                                                                                                             |
# | 10 | Treasury and other revenue                                                        | $36.7 million   | not specified        | Treasury and other revenue: S$36.7 million, up 44.3% from S$25.4 million.                                                                                                                                                                |
# | 11 | Equities – Cash revenue                                                           | $159.6 million  | not specified        | Equities – Cash revenue declined by 5.6% to S$159.6 million ( S$169.1 million ) and accounted for 26.9 % (29.6 %) of total revenue.                                                                                                      |
# | 12 | Listing revenue                                                                   | $14.6 million   | not specified        | Listing revenue: S$14.6 million, down 3.3% from S$15.1 million.                                                                                                                                                                          |
# | 13 | Trading and clearing revenue                                                      | $77.2 million   | not specified        | Trading and clearing revenue: S$77.2 million, down 13.9 % from S$89.6 million.                                                                                                                                                           |
# | 14 | Securities settlement, depository management, corporate actions and other revenue | $67.9 million   | not specified        | Securities settlement, depository management, corporate actions and other revenue: S$67.9 million, up 5.3% from S$64.5 million.                                                                                                          |
# | 15 | trading and clearing revenue                                                      | $123.2 million  | 1H FY2024            | Trading and clearing revenue: S$123.2 million, down 15.3 % from S$145.4 million                                                                                                                                                          |
# | 16 | treasury and other revenue                                                        | $37.5 million   | 1H FY2024            | Treasury and other revenue: S$37.5 million, up 37.7% from S$27.2 million                                                                                                                                                                 |
# | 17 | market data revenue                                                               | $24.2 million   | 1H FY2024            | Market data revenue: S$24.2 million, up 9.9% from S$22.0 million                                                                                                                                                                         |
# | 18 | connectivity revenue                                                              | $38.5 million   | 1H FY2024            | Connectivity revenue: S$38.5 million, up 8.7% from S$35.4 million                                                                                                                                                                        |
# | 19 | indices and other revenue                                                         | $57.4 million   | 1H FY2024            | Indices and other revenue: S$57.4 million, up 6.8% from S$53.8 million                                                                                                                                                                   |
# | 20 | net profit                                                                        | S$289.7 million | first half of FY2024 | 5% to S$289.7 million (S$279.9 million), which excludes amortisation of purchased intangible assets.                                                                                                                                     |
# | 21 | total capital expenditure                                                         | S$18.5 million  | not specified        | Total capital expenditure was S$18.5 million ( S$17.8 million). These investments include upgrades to our Titan OTC trade reporting system, modernisation of our technology infrastructure and consolidation of our office spaces.       |
# | 22 | expenses                                                                          | not specified   | FY2024               | Expense growth in FY2024 is likely to be similar to the 3% year -on-year expense growth rate observed in the first half of FY2024, lower than the previously guided mid -single digit percentage range.                                  |
# | 23 | projected capital expenditure                                                     | S$70-75 million | FY2024               | Our projected capital expenditure for FY2024 is anticipated to be within S$70-75 million, lower than our previously guided S$75-80 million range.                                                                                        |
